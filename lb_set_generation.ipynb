# %% [markdown]
# ### SET GENERATION

# %%
import random
import json
from lb_set_data import *
from lb_set_tools import *

# %%
# set seed
random.seed(10)

# generate chars
set_size = 10000
chance_girl = 0.4
export_list = []
for i in range(set_size):
    is_girl = random.random() < chance_girl
    char = build_girl_char() if is_girl else build_boy_char()
    export_list.append(char)
print("generated", len(export_list), "chars")
# Out:
# generated 10000 chars

# %%
# resolve twins
resolve_costume_twins(export_list)
resolve_twins(export_list)
# Out:
# id 392 duplicate costume found - style12 style05 style05 - rerolling... 0
# id 1605 duplicate costume found - style08 style05 style05 - rerolling... 0
# id 1865 duplicate costume found - style16 style03 style05 - rerolling... 0
# id 1865 duplicate costume found - style16 style05 style06 - rerolling... 1
# id 2168 duplicate costume found - style05 style05 style06 - rerolling... 0
# id 3342 duplicate costume found - style12 style05 style05 - rerolling... 0
# id 3841 duplicate costume found - style09 style05 style06 - rerolling... 0
# id 3841 duplicate costume found - style09 style05 style06 - rerolling... 1
# id 4077 duplicate costume found - style01 style05 style04 - rerolling... 0
# id 4128 duplicate costume found - style14 style05 style01 - rerolling... 0
# id 4128 duplicate costume found - style14 style05 style05 - rerolling... 1
# id 4439 duplicate costume found - style14 style03 style05 - rerolling... 0
# id 4735 duplicate costume found - style12 style05 style05 - rerolling... 0
# id 4764 duplicate costume found - style15 style03 style04 - rerolling... 0
# id 4764 duplicate costume found - style15 style04 style04 - rerolling... 1
# id 5514 duplicate costume found - style08 style05 style05 - rerolling... 0
# id 5514 duplicate costume found - style08 style05 style05 - rerolling... 1
# id 5514 duplicate costume found - style08 style04 style04 - rerolling... 2
# id 5514 duplicate costume found - style08 style05 style05 - rerolling... 3
# id 5625 duplicate costume found - style12 style05 style05 - rerolling... 0
# id 5625 duplicate costume found - style12 style05 style04 - rerolling... 1
# id 5921 duplicate costume found - style16 style03 style05 - rerolling... 0
# id 6664 duplicate costume found - style12 style05 style05 - rerolling... 0
# id 6664 duplicate costume found - style12 style05 style04 - rerolling... 1
# id 6664 duplicate costume found - style12 style05 style05 - rerolling... 2
# id 6664 duplicate costume found - style12 style05 style06 - rerolling... 3
# id 6988 duplicate costume found - style12 style05 style06 - rerolling... 0
# id 6988 duplicate costume found - style12 style05 style06 - rerolling... 1
# id 7804 duplicate costume found - style14 style05 style05 - rerolling... 0
# id 8225 duplicate costume found - style08 style05 style05 - rerolling... 0
# id 8428 duplicate costume found - style20 style05 style05 - rerolling... 0
# id 8428 duplicate costume found - style20 style05 style05 - rerolling... 1
# id 8447 duplicate costume found - style15 style04 style05 - rerolling... 0
# id 8653 duplicate costume found - style06 style03 style05 - rerolling... 0
# id 8822 duplicate costume found - style06 style05 style05 - rerolling... 0
# id 9052 duplicate costume found - style12 style05 style06 - rerolling... 0
# id 9393 duplicate costume found - style14 style05 style01 - rerolling... 0
# id 9393 duplicate costume found - style14 style05 style06 - rerolling... 1
# finding twins...
# no twins found

# %%
# set chars rarities
chars_rarities = []
rarities = ['common', 'uncommon', 'rare', 'epic', 'legendary', 'iridescent']

for char in export_list:
    points = get_char_points(char)
    rarity = get_char_rarity(points, char['gender'])
    char['rarity'] = rarity
    chars_rarities.append(rarity)

for gender in ['male', 'female']:
    gender_rarities = [x for i, x in enumerate(chars_rarities) if export_list[i]['gender'] == gender]
    print(gender, "rarities:")
    for rarity in rarities:
        print(rarity[:6], "\t\t{:.2f} %".format(gender_rarities.count(rarity) / len(gender_rarities) * 100))
    print('\n')
print("total rarities:")
for rarity in rarities:
    print(rarity[:6], "\t\t{:.2f} %".format(chars_rarities.count(rarity) / len(chars_rarities) * 100))
# Out:
# male rarities:
# common 		29.82 %
# uncomm 		29.74 %
# rare 		23.30 %
# epic 		10.55 %
# legend 		5.41 %
# irides 		1.18 %
#
#
# female rarities:
# common 		34.91 %
# uncomm 		30.48 %
# rare 		17.98 %
# epic 		9.77 %
# legend 		5.41 %
# irides 		1.45 %
#
#
# total rarities:
# common 		31.89 %
# uncomm 		30.04 %
# rare 		21.14 %
# epic 		10.23 %
# legend 		5.41 %
# irides 		1.29 %

# %%
### show statistics

# set length
set_length = len(export_list)
print("set length:", set_length)

# count: male / female 
male_count = len([True for char in export_list if char['gender'] == 'male'])
female_count = set_length - male_count
print("male count:", male_count, '(', round(male_count / set_length * 100, 2), '%)')
print("female count:", female_count, '(', round(female_count / set_length * 100, 2), '%)\n')

# count: rarities
rarity_counters = [chars_rarities.count(x) for x in rarities]
for ind, counter in enumerate(rarity_counters): 
    print(rarities[ind], "count:", counter, '(', round(counter / set_length * 100, 2), '%)')


unique_elements = {tuple(sorted(d.items())) for d in export_list}
is_all_unique = len(unique_elements) == len(export_list)
print("\nall unique:", is_all_unique)
if not is_all_unique: print("number of twins:", len(export_list) - len(unique_elements))

# uses display name dictionary to account for same visuals with different styleIDs
print("\nstyles count:")
for slot in boy_drops_ref:
    assert(list(boy_drops_ref) == list(girl_drops_ref))
    print (slot)
    boy_display_options = list(boy_styles_display[slot].values())
    girl_display_options = list(girl_styles_display[slot].values())
    display_options = boy_display_options + [x for x in girl_display_options if x not in boy_display_options]
    chars_display_values = [get_char_style_display(char, slot) for char in export_list]
    for display_name in display_options:
        display_count = chars_display_values.count(display_name)
        print("\t", display_name, ":\t", display_count, '(', round(display_count / set_length * 100, 2), '%)')
# Out:
# set length: 10000
# male count: 5935 ( 59.35 %)
# female count: 4065 ( 40.65 %)
#
# common count: 3189 ( 31.89 %)
# uncommon count: 3004 ( 30.04 %)
# rare count: 2114 ( 21.14 %)
# epic count: 1023 ( 10.23 %)
# legendary count: 541 ( 5.41 %)
# iridescent count: 129 ( 1.29 %)
#
# all unique: True
#
# styles count:
# costume
# 	 none :	 9871 ( 98.71 %)
# 	 MTV Astronaut Costume :	 8 ( 0.08 %)
# 	 Sloth Costume :	 5 ( 0.05 %)
# 	 Panda Costume :	 4 ( 0.04 %)
# 	 Polar Bear Costume :	 3 ( 0.03 %)
# 	 Brown Bear Costume :	 5 ( 0.05 %)
# 	 Chicken Costume :	 9 ( 0.09 %)
# 	 Snake Costume :	 7 ( 0.07 %)
# 	 Gray Cat Costume :	 6 ( 0.06 %)
# 	 Orange Cat Costume :	 8 ( 0.08 %)
# 	 Black Cat Costume :	 1 ( 0.01 %)
# 	 Calico Cat Costume :	 8 ( 0.08 %)
# 	 Pug Costume :	 13 ( 0.13 %)
# 	 Monkey Costume :	 4 ( 0.04 %)
# 	 Crocodile Costume :	 9 ( 0.09 %)
# 	 Brown Bull Costume :	 8 ( 0.08 %)
# 	 Black Bull Costume :	 6 ( 0.06 %)
# 	 Alien Costume :	 6 ( 0.06 %)
# 	 Corgi Costume :	 4 ( 0.04 %)
# 	 Owl Costume :	 7 ( 0.07 %)
# 	 Frog Costume :	 8 ( 0.08 %)
# hat
# 	 none :	 7571 ( 75.71 %)
# 	 Blue Conductor's Hat :	 56 ( 0.56 %)
# 	 Chef's Hat :	 78 ( 0.78 %)
# 	 Cowboy Hat :	 61 ( 0.61 %)
# 	 Penguin Hat :	 48 ( 0.48 %)
# 	 Dog Hat :	 35 ( 0.35 %)
# 	 Red & White Cap :	 53 ( 0.53 %)
# 	 Red Stripes Cap :	 96 ( 0.96 %)
# 	 Red Cap :	 88 ( 0.88 %)
# 	 Fire Cap :	 99 ( 0.99 %)
# 	 Duck Cap :	 28 ( 0.28 %)
# 	 Viking Helmet :	 25 ( 0.25 %)
# 	 Policeman Cap :	 70 ( 0.7 %)
# 	 Boat Captain Hat :	 27 ( 0.27 %)
# 	 Gray Coonskin Hat :	 92 ( 0.92 %)
# 	 White Coonskin Hat :	 88 ( 0.88 %)
# 	 Gray Bowler Hat :	 39 ( 0.39 %)
# 	 Brown Bowler Hat :	 39 ( 0.39 %)
# 	 Gray Ushanka :	 90 ( 0.9 %)
# 	 Brown Ushanka :	 71 ( 0.71 %)
# 	 Green Ushanka :	 49 ( 0.49 %)
# 	 Green Bandana :	 105 ( 1.05 %)
# 	 Blue Bandana :	 89 ( 0.89 %)
# 	 Purple Bandana :	 76 ( 0.76 %)
# 	 Red Bandana :	 86 ( 0.86 %)
# 	 Blue Beanie :	 98 ( 0.98 %)
# 	 Green Beanie :	 91 ( 0.91 %)
# 	 Yellow Beanie :	 88 ( 0.88 %)
# 	 Purple Beanie :	 88 ( 0.88 %)
# 	 Red Backwards Cap :	 39 ( 0.39 %)
# 	 Green Backwards Cap :	 46 ( 0.46 %)
# 	 Blue Backwards Cap :	 59 ( 0.59 %)
# 	 Yellow Backwards Cap :	 54 ( 0.54 %)
# 	 Pink Conductor's Hat :	 24 ( 0.24 %)
# 	 Witch Hat :	 24 ( 0.24 %)
# 	 White Floppy Hat :	 25 ( 0.25 %)
# 	 Yellow Sun Hat :	 11 ( 0.11 %)
# 	 Little Brown Bowler Hat :	 24 ( 0.24 %)
# 	 Blue Newsboy Hat :	 38 ( 0.38 %)
# 	 Blue Heart Headband :	 36 ( 0.36 %)
# 	 Red Heart Headband :	 17 ( 0.17 %)
# 	 Red Bow Headband :	 43 ( 0.43 %)
# 	 Blue Bow Headband :	 36 ( 0.36 %)
# hair
# 	 none :	 125 ( 1.25 %)
# 	 Blond Short Hair :	 215 ( 2.15 %)
# 	 Brown Short Hair :	 576 ( 5.76 %)
# 	 Dark Gray Short Hair :	 506 ( 5.06 %)
# 	 Light Gray Short Hair :	 342 ( 3.42 %)
# 	 Pink Short Hair :	 55 ( 0.55 %)
# 	 Red Short Hair :	 152 ( 1.52 %)
# 	 Blond Pompadour Hair :	 52 ( 0.52 %)
# 	 Brown Pompadour Hair :	 179 ( 1.79 %)
# 	 Dark Gray Pompadour Hair :	 167 ( 1.67 %)
# 	 Light Gray Pompadour Hair :	 112 ( 1.12 %)
# 	 Pink Pompadour Hair :	 24 ( 0.24 %)
# 	 Red Pompadour Hair :	 49 ( 0.49 %)
# 	 Blond Spiky Dreadlocks Hair :	 70 ( 0.7 %)
# 	 Brown Spiky Dreadlocks Hair :	 159 ( 1.59 %)
# 	 Dark Gray Spiky Dreadlocks Hair :	 138 ( 1.38 %)
# 	 Light Gray Spiky Dreadlocks Hair :	 97 ( 0.97 %)
# 	 Pink Spiky Dreadlocks Hair :	 18 ( 0.18 %)
# 	 Red Spiky Dreadlocks Hair :	 44 ( 0.44 %)
# 	 Blond Emo Swoop Hair :	 53 ( 0.53 %)
# 	 Brown Emo Swoop Hair :	 182 ( 1.82 %)
# 	 Dark Gray Emo Swoop Hair :	 167 ( 1.67 %)
# 	 Light Gray Emo Swoop Hair :	 91 ( 0.91 %)
# 	 Pink Emo Swoop Hair :	 20 ( 0.2 %)
# 	 Red Emo Swoop Hair :	 36 ( 0.36 %)
# 	 Blond Afro Hair :	 101 ( 1.01 %)
# 	 Brown Afro Hair :	 278 ( 2.78 %)
# 	 Dark Gray Afro Hair :	 260 ( 2.6 %)
# 	 Light Gray Afro Hair :	 206 ( 2.06 %)
# 	 Pink Afro Hair :	 30 ( 0.3 %)
# 	 Red Afro Hair :	 90 ( 0.9 %)
# 	 Blond Top Knot Hair :	 76 ( 0.76 %)
# 	 Brown Top Knot Hair :	 163 ( 1.63 %)
# 	 Dark Gray Top Knot Hair :	 138 ( 1.38 %)
# 	 Light Gray Top Knot Hair :	 92 ( 0.92 %)
# 	 Pink Top Knot Hair :	 18 ( 0.18 %)
# 	 Red Top Knot Hair :	 42 ( 0.42 %)
# 	 Blond Mohawk Hair :	 52 ( 0.52 %)
# 	 Brown Mohawk Hair :	 151 ( 1.51 %)
# 	 Dark Gray Mohawk Hair :	 165 ( 1.65 %)
# 	 Light Gray Mohawk Hair :	 113 ( 1.13 %)
# 	 Pink Mohawk Hair :	 23 ( 0.23 %)
# 	 Red Mohawk Hair :	 33 ( 0.33 %)
# 	 Blond Bald Hair :	 56 ( 0.56 %)
# 	 Brown Bald Hair :	 161 ( 1.61 %)
# 	 Dark Gray Bald Hair :	 136 ( 1.36 %)
# 	 Light Gray Bald Hair :	 125 ( 1.25 %)
# 	 Pink Bald Hair :	 20 ( 0.2 %)
# 	 Red Bald Hair :	 43 ( 0.43 %)
# 	 Backwards Cap Blond Hair :	 17 ( 0.17 %)
# 	 Backwards Cap Brown Hair :	 69 ( 0.69 %)
# 	 Backwards Cap Dark Gray Hair :	 60 ( 0.6 %)
# 	 Backwards Cap Light Gray Hair :	 32 ( 0.32 %)
# 	 Backwards Cap Pink Hair :	 8 ( 0.08 %)
# 	 Backwards Cap Red Hair :	 12 ( 0.12 %)
# 	 Blond Chanel Hair :	 123 ( 1.23 %)
# 	 Brown Chanel Hair :	 368 ( 3.68 %)
# 	 Dark Gray Chanel Hair :	 360 ( 3.6 %)
# 	 Light Gray Chanel Hair :	 232 ( 2.32 %)
# 	 Pink Chanel Hair :	 59 ( 0.59 %)
# 	 Red Chanel Hair :	 101 ( 1.01 %)
# 	 Blond Long Hair :	 43 ( 0.43 %)
# 	 Brown Long Hair :	 139 ( 1.39 %)
# 	 Dark Gray Long Hair :	 130 ( 1.3 %)
# 	 Light Gray Long Hair :	 74 ( 0.74 %)
# 	 Pink Long Hair :	 14 ( 0.14 %)
# 	 Red Long Hair :	 26 ( 0.26 %)
# 	 Blond Medium Shag Hair :	 42 ( 0.42 %)
# 	 Brown Medium Shag Hair :	 106 ( 1.06 %)
# 	 Dark Gray Medium Shag Hair :	 111 ( 1.11 %)
# 	 Light Gray Medium Shag Hair :	 69 ( 0.69 %)
# 	 Pink Medium Shag Hair :	 14 ( 0.14 %)
# 	 Red Medium Shag Hair :	 32 ( 0.32 %)
# 	 Blond Side Shaved Hair :	 49 ( 0.49 %)
# 	 Brown Side Shaved Hair :	 110 ( 1.1 %)
# 	 Dark Gray Side Shaved Hair :	 120 ( 1.2 %)
# 	 Light Gray Side Shaved Hair :	 79 ( 0.79 %)
# 	 Pink Side Shaved Hair :	 11 ( 0.11 %)
# 	 Red Side Shaved Hair :	 19 ( 0.19 %)
# 	 Blond Curly Short Hair :	 47 ( 0.47 %)
# 	 Brown Curly Short Hair :	 122 ( 1.22 %)
# 	 Dark Gray Curly Short Hair :	 109 ( 1.09 %)
# 	 Light Gray Curly Short Hair :	 75 ( 0.75 %)
# 	 Pink Curly Short Hair :	 12 ( 0.12 %)
# 	 Red Curly Short Hair :	 35 ( 0.35 %)
# 	 Blond Ponytail Hair :	 46 ( 0.46 %)
# 	 Brown Ponytail Hair :	 111 ( 1.11 %)
# 	 Dark Gray Ponytail Hair :	 123 ( 1.23 %)
# 	 Light Gray Ponytail Hair :	 70 ( 0.7 %)
# 	 Pink Ponytail Hair :	 12 ( 0.12 %)
# 	 Red Ponytail Hair :	 25 ( 0.25 %)
# 	 Blond Sweeping Pixie Hair :	 50 ( 0.5 %)
# 	 Brown Sweeping Pixie Hair :	 90 ( 0.9 %)
# 	 Dark Gray Sweeping Pixie Hair :	 104 ( 1.04 %)
# 	 Light Gray Sweeping Pixie Hair :	 89 ( 0.89 %)
# 	 Pink Sweeping Pixie Hair :	 14 ( 0.14 %)
# 	 Red Sweeping Pixie Hair :	 36 ( 0.36 %)
# glasses
# 	 none :	 4044 ( 40.44 %)
# 	 Modern Glasses :	 380 ( 3.8 %)
# 	 Big Frame Blue Glasses :	 605 ( 6.05 %)
# 	 Big Frame Green Glasses :	 384 ( 3.84 %)
# 	 Big Frame Red Glasses :	 252 ( 2.52 %)
# 	 Yellow Aviator Glasses :	 208 ( 2.08 %)
# 	 Teal Aviator Glasses :	 343 ( 3.43 %)
# 	 Gray Aviator Glasses :	 603 ( 6.03 %)
# 	 Purple Aviator Glasses :	 252 ( 2.52 %)
# 	 Semi-Rimless Glasses :	 347 ( 3.47 %)
# 	 Full-Rimmed Glasses :	 631 ( 6.31 %)
# 	 Small Teashade Sunglasses :	 338 ( 3.38 %)
# 	 Red Teashade Sunglasses :	 350 ( 3.5 %)
# 	 Old 3D Glasses :	 102 ( 1.02 %)
# 	 Black Sunglasses :	 618 ( 6.18 %)
# 	 Monocle :	 229 ( 2.29 %)
# 	 White Framed Sunglasses :	 112 ( 1.12 %)
# 	 Red Framed Sunglasses :	 84 ( 0.84 %)
# 	 Big Blue Circular Glasses :	 118 ( 1.18 %)
# eyes
# 	 none :	 0 ( 0.0 %)
# 	 Red Eyes :	 1185 ( 11.85 %)
# 	 Pink Eyes :	 569 ( 5.69 %)
# 	 Green Eyes :	 1779 ( 17.79 %)
# 	 Blue Eyes :	 1810 ( 18.1 %)
# 	 Black Eyes :	 4657 ( 46.57 %)
# nose
# 	 none :	 0 ( 0.0 %)
# 	 Small Nose :	 5107 ( 51.07 %)
# 	 Medium Nose :	 2997 ( 29.97 %)
# 	 Big Nose :	 1896 ( 18.96 %)
# beard
# 	 none :	 5875 ( 58.75 %)
# 	 Blond Goatee :	 54 ( 0.54 %)
# 	 Brown Goatee :	 125 ( 1.25 %)
# 	 Dark Gray Goatee :	 107 ( 1.07 %)
# 	 Light Gray Goatee :	 85 ( 0.85 %)
# 	 Pink Goatee :	 12 ( 0.12 %)
# 	 Red Goatee :	 42 ( 0.42 %)
# 	 Blond Imperial Mustache :	 43 ( 0.43 %)
# 	 Brown Imperial Mustache :	 135 ( 1.35 %)
# 	 Dark Gray Imperial Mustache :	 127 ( 1.27 %)
# 	 Light Gray Imperial Mustache :	 72 ( 0.72 %)
# 	 Pink Imperial Mustache :	 25 ( 0.25 %)
# 	 Red Imperial Mustache :	 22 ( 0.22 %)
# 	 Blond Walrus Mustache :	 42 ( 0.42 %)
# 	 Brown Walrus Mustache :	 113 ( 1.13 %)
# 	 Dark Gray Walrus Mustache :	 116 ( 1.16 %)
# 	 Light Gray Walrus Mustache :	 92 ( 0.92 %)
# 	 Pink Walrus Mustache :	 14 ( 0.14 %)
# 	 Red Walrus Mustache :	 33 ( 0.33 %)
# 	 Blond Zappa Moustache :	 46 ( 0.46 %)
# 	 Brown Zappa Moustache :	 127 ( 1.27 %)
# 	 Dark Gray Zappa Moustache :	 106 ( 1.06 %)
# 	 Light Gray Zappa Moustache :	 78 ( 0.78 %)
# 	 Pink Zappa Moustache :	 9 ( 0.09 %)
# 	 Red Zappa Moustache :	 34 ( 0.34 %)
# 	 Blond Mutton Chops :	 44 ( 0.44 %)
# 	 Brown Mutton Chops :	 128 ( 1.28 %)
# 	 Dark Gray Mutton Chops :	 128 ( 1.28 %)
# 	 Ligth Gray Mutton Chops :	 67 ( 0.67 %)
# 	 Pink Mutton Chops :	 13 ( 0.13 %)
# 	 Red Mutton Chops :	 28 ( 0.28 %)
# 	 Blond Soul Patch :	 37 ( 0.37 %)
# 	 Brown Soul Patch :	 140 ( 1.4 %)
# 	 Dark Gray Soul Patch :	 121 ( 1.21 %)
# 	 Light Gray Soul Patch :	 69 ( 0.69 %)
# 	 Pink Soul Patch :	 10 ( 0.1 %)
# 	 Red Soul Patch :	 26 ( 0.26 %)
# 	 Blond Full Goatee :	 47 ( 0.47 %)
# 	 Brown Full Goatee :	 114 ( 1.14 %)
# 	 Dark Gray Full Goatee :	 91 ( 0.91 %)
# 	 Light Gray Full Goatee :	 89 ( 0.89 %)
# 	 Pink Full Goatee :	 18 ( 0.18 %)
# 	 Red Full Goatee :	 43 ( 0.43 %)
# 	 Blond Moustache :	 51 ( 0.51 %)
# 	 Brown Moustache :	 117 ( 1.17 %)
# 	 Dark Gray Moustache :	 114 ( 1.14 %)
# 	 Light Gray Moustache :	 58 ( 0.58 %)
# 	 Pink Moustache :	 23 ( 0.23 %)
# 	 Red Moustache :	 38 ( 0.38 %)
# 	 Blond Full Beard :	 45 ( 0.45 %)
# 	 Brown Full Beard :	 114 ( 1.14 %)
# 	 Dark Gray Full Beard :	 98 ( 0.98 %)
# 	 Light Gray Full Beard :	 73 ( 0.73 %)
# 	 Pink Full Beard :	 13 ( 0.13 %)
# 	 Red Full Beard :	 31 ( 0.31 %)
# 	 Blond Thick Moustache :	 42 ( 0.42 %)
# 	 Brown Thick Moustache :	 105 ( 1.05 %)
# 	 Dark Gray Thick Moustache :	 96 ( 0.96 %)
# 	 Light Gray Thick Moustache :	 74 ( 0.74 %)
# 	 Pink Thick Moustache :	 10 ( 0.1 %)
# 	 Red Thick Moustache :	 39 ( 0.39 %)
# 	 Stubble Beard :	 112 ( 1.12 %)
# bowtie
# 	 none :	 9439 ( 94.39 %)
# 	 Green Bowtie :	 149 ( 1.49 %)
# 	 Blue Bowtie :	 138 ( 1.38 %)
# 	 Yellow Bowtie :	 151 ( 1.51 %)
# 	 Red Bowtie :	 123 ( 1.23 %)
# jacket
# 	 none :	 7632 ( 76.32 %)
# 	 Gray Jacket - Black Sleeves :	 262 ( 2.62 %)
# 	 Red Jacket - White Sleeves :	 292 ( 2.92 %)
# 	 Black Jacket - Yellow Sleeves :	 266 ( 2.66 %)
# 	 Blue MTV Jacket :	 91 ( 0.91 %)
# 	 Blue Stripes Jacket :	 269 ( 2.69 %)
# 	 Red Jacket :	 260 ( 2.6 %)
# 	 Black Jacket :	 261 ( 2.61 %)
# 	 Big Black Jacket :	 49 ( 0.49 %)
# 	 Big Green Jacket :	 46 ( 0.46 %)
# 	 Big Brown Jacket :	 60 ( 0.6 %)
# 	 Big Teal Jacket :	 54 ( 0.54 %)
# 	 Big Pink Jacket :	 33 ( 0.33 %)
# 	 Small Blue Jacket :	 91 ( 0.91 %)
# 	 Small Dark Teal Jacket :	 84 ( 0.84 %)
# 	 Small Black Jacket :	 75 ( 0.75 %)
# 	 Small Yellow Jacket - Black Sleeves :	 67 ( 0.67 %)
# 	 Small Pink Jacket :	 27 ( 0.27 %)
# 	 Black Jacket - Pink Sleeves :	 81 ( 0.81 %)
# torso
# 	 none :	 129 ( 1.29 %)
# 	 Apron Shirt :	 98 ( 0.98 %)
# 	 Green Hawaiian Shirt :	 116 ( 1.16 %)
# 	 Red Hawaiian Shirt :	 53 ( 0.53 %)
# 	 Blue Hawaiian Shirt :	 161 ( 1.61 %)
# 	 Blue Shirt - Black Sleeves :	 178 ( 1.78 %)
# 	 Black & Red Shirt :	 190 ( 1.9 %)
# 	 Black & Yellow Shirt :	 186 ( 1.86 %)
# 	 Blue Polo Shirt :	 269 ( 2.69 %)
# 	 White Polo Shirt :	 307 ( 3.07 %)
# 	 Yellow Shirt - Blue Sleeves :	 427 ( 4.27 %)
# 	 Pink & White Wave Shirt :	 161 ( 1.61 %)
# 	 Gray & Yellow Wave Shirt :	 270 ( 2.7 %)
# 	 Round Blue Shirt :	 265 ( 2.65 %)
# 	 Round Purple Shirt :	 255 ( 2.55 %)
# 	 Round Green Shirt :	 262 ( 2.62 %)
# 	 Pink Shirt :	 165 ( 1.65 %)
# 	 Gray Shirt :	 387 ( 3.87 %)
# 	 Green Shirt :	 416 ( 4.16 %)
# 	 Blue Shirt :	 440 ( 4.4 %)
# 	 Red Shirt :	 414 ( 4.14 %)
# 	 Pink Skull Shirt :	 109 ( 1.09 %)
# 	 Black Skull Shirt :	 96 ( 0.96 %)
# 	 Yellow & Black Windbreaker :	 249 ( 2.49 %)
# 	 Pink & White Stripes Sweater :	 67 ( 0.67 %)
# 	 Gray & Blue Stripes Sweater :	 98 ( 0.98 %)
# 	 Green & Yellow Stripes Sweater :	 114 ( 1.14 %)
# 	 Blue & Blue Stripes Sweater :	 100 ( 1.0 %)
# 	 Brown & Gray Stripes Sweater :	 270 ( 2.7 %)
# 	 Pink Sweater :	 61 ( 0.61 %)
# 	 Gray Sweater :	 320 ( 3.2 %)
# 	 Green Sweater :	 99 ( 0.99 %)
# 	 Blue Sweater :	 85 ( 0.85 %)
# 	 Brown Sweater :	 289 ( 2.89 %)
# 	 Blue Stripes Overalls :	 52 ( 0.52 %)
# 	 Yellow Overalls :	 76 ( 0.76 %)
# 	 Blue Overalls :	 68 ( 0.68 %)
# 	 Green Tracksuit :	 175 ( 1.75 %)
# 	 Gray Tracksuit :	 117 ( 1.17 %)
# 	 Red Tracksuit :	 99 ( 0.99 %)
# 	 Red Robe :	 27 ( 0.27 %)
# 	 Black Vest :	 293 ( 2.93 %)
# 	 Caramel Vest :	 254 ( 2.54 %)
# 	 Red Vest :	 77 ( 0.77 %)
# 	 Green Vest :	 79 ( 0.79 %)
# 	 Gray Vest :	 111 ( 1.11 %)
# 	 Green Summer Shirt :	 119 ( 1.19 %)
# 	 Baby Blue Summer Shirt :	 154 ( 1.54 %)
# 	 White Summer Shirt :	 147 ( 1.47 %)
# 	 Gray & White Shirt :	 124 ( 1.24 %)
# 	 Pink Stripes Overalls :	 17 ( 0.17 %)
# 	 Green Overalls :	 75 ( 0.75 %)
# 	 Purple Strapless Dress :	 27 ( 0.27 %)
# 	 Blue Strapless Dress :	 69 ( 0.69 %)
# 	 Yellow Strapless Dress :	 86 ( 0.86 %)
# 	 Red Strapless Dress :	 13 ( 0.13 %)
# 	 Gray Strapless Dress :	 128 ( 1.28 %)
# 	 Green Strapless Dress :	 44 ( 0.44 %)
# 	 Pink Strapless Dress :	 37 ( 0.37 %)
# 	 Black Strapless Dress :	 57 ( 0.57 %)
# 	 Green Sundress :	 71 ( 0.71 %)
# 	 Black Sundress :	 37 ( 0.37 %)
# 	 Red Sundress :	 24 ( 0.24 %)
# 	 Pink Sundress :	 30 ( 0.3 %)
# 	 Yellow Sundress :	 86 ( 0.86 %)
# 	 Light Gray Sweater :	 39 ( 0.39 %)
# 	 Orange Sweater :	 31 ( 0.31 %)
# 	 Yellow Sweater :	 31 ( 0.31 %)
# 	 Fancy Gray Coat :	 20 ( 0.2 %)
# legs
# 	 none :	 1544 ( 15.44 %)
# 	 Red Pants :	 436 ( 4.36 %)
# 	 Blue MTV Pants :	 166 ( 1.66 %)
# 	 Black Pants :	 454 ( 4.54 %)
# 	 Gray Pants :	 679 ( 6.79 %)
# 	 Blue Pants :	 702 ( 7.02 %)
# 	 Green Pants :	 654 ( 6.54 %)
# 	 White Pants :	 273 ( 2.73 %)
# 	 Lime Pants :	 422 ( 4.22 %)
# 	 Purple Pants :	 236 ( 2.36 %)
# 	 Pink Pants :	 84 ( 0.84 %)
# 	 Yellow Pants :	 168 ( 1.68 %)
# 	 Blue & Black Shorts :	 441 ( 4.41 %)
# 	 Red Shorts :	 469 ( 4.69 %)
# 	 Gray Shorts :	 445 ( 4.45 %)
# 	 Blue Shorts :	 654 ( 6.54 %)
# 	 Green Shorts :	 657 ( 6.57 %)
# 	 White Shorts :	 256 ( 2.56 %)
# 	 Lime Shorts :	 442 ( 4.42 %)
# 	 Purple Shorts :	 275 ( 2.75 %)
# 	 Pink Shorts :	 81 ( 0.81 %)
# 	 Yellow Shorts :	 172 ( 1.72 %)
# 	 Pink & Black Skirt :	 56 ( 0.56 %)
# 	 Pink Skirt :	 21 ( 0.21 %)
# 	 White Skirt :	 138 ( 1.38 %)
# 	 Blue Skirt :	 75 ( 0.75 %)
# shoes
# 	 none :	 129 ( 1.29 %)
# 	 Red Boots :	 178 ( 1.78 %)
# 	 White Boots :	 297 ( 2.97 %)
# 	 Purple Boots :	 269 ( 2.69 %)
# 	 Green Boots :	 495 ( 4.95 %)
# 	 Pink Boots :	 122 ( 1.22 %)
# 	 Blue Boots :	 791 ( 7.91 %)
# 	 Brown Boots :	 806 ( 8.06 %)
# 	 Black & Gray Boots :	 330 ( 3.3 %)
# 	 Black Boots :	 792 ( 7.92 %)
# 	 White Cowboy Boots :	 196 ( 1.96 %)
# 	 Pink Cowboy Boots :	 65 ( 0.65 %)
# 	 Red Cowboy Boots :	 129 ( 1.29 %)
# 	 Green Cowboy Boots :	 316 ( 3.16 %)
# 	 Brown Cowboy Boots :	 334 ( 3.34 %)
# 	 Black Flip-Flops :	 825 ( 8.25 %)
# 	 White Flip-Flops :	 793 ( 7.93 %)
# 	 Brown Flip-Flops :	 482 ( 4.82 %)
# 	 Red Flip-Flops :	 496 ( 4.96 %)
# 	 Orange Slippers :	 309 ( 3.09 %)
# 	 Blue Slippers :	 527 ( 5.27 %)
# 	 Pink Slippers :	 198 ( 1.98 %)
# 	 Purple Shoes :	 90 ( 0.9 %)
# 	 Teal Shoes :	 186 ( 1.86 %)
# 	 Blue Shoes :	 296 ( 2.96 %)
# 	 Black Shoes :	 293 ( 2.93 %)
# 	 Salmon Shoes :	 102 ( 1.02 %)
# 	 Pink Shoes :	 34 ( 0.34 %)
# 	 Marigold Shoes :	 37 ( 0.37 %)
# 	 Royal Blue Shoes :	 83 ( 0.83 %)
# skin
# 	 none :	 0 ( 0.0 %)
# 	 Pink Rose :	 994 ( 9.94 %)
# 	 Sage Green :	 327 ( 3.27 %)
# 	 Pale Sky Blue :	 663 ( 6.63 %)
# 	 Rose Gold :	 2615 ( 26.15 %)
# 	 Rosy Brown :	 2699 ( 26.99 %)
# 	 Dark Taupe :	 2702 ( 27.02 %)

# %%
# export data file
with open("export_set_10000.json", "w") as outfile:
    json.dump(export_list, outfile)
